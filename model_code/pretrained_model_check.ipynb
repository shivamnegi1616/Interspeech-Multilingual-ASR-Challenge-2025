# %%
import torch
import torchaudio
from transformers import Wav2Vec2ForCTC, Wav2Vec2Processor

MODEL_ID_FRENCH = "jonatasgrosman/wav2vec2-large-xlsr-53-french"

MODEL_ID_GERMAN = "jonatasgrosman/wav2vec2-xls-r-1b-german"

MODEL_ID_ITALIAN = "dbdmg/wav2vec2-xls-r-300m-italian-robust"

MODEL_ID_JAPNESE = "jonatasgrosman/wav2vec2-large-xlsr-53-japanese"

# %%
device = 'cuda:0' if torch.cuda.is_available() else 'cpu'

# %%
device
# Out:
# 'cuda:0'

# %%
def multilingual_pretrained_asr(MODEL_ID, input_audio_path, device):
    
    wav, sr = torchaudio.load(input_audio_path)
    
    processor = Wav2Vec2Processor.from_pretrained(MODEL_ID)
    model = Wav2Vec2ForCTC.from_pretrained(MODEL_ID)
    model = model.to(device)
    
    inputs = processor(wav, sampling_rate = 16_000, return_tensors = "pt", padding = True)
    
    inputs = inputs.to(device)
    
    with torch.no_grad():
        
        input_values = inputs['input_values'].squeeze(0)
        
        logits = model(input_values, attention_mask = inputs.attention_mask).logits
    
    predicted_ids = torch.argmax(logits, dim = -1)
    
    predicted_sentences = processor.batch_decode(predicted_ids)

    return predicted_sentences

# %% [markdown]
# ## Loading the french audio

# %%
french_audio_path = "/home/IITB/ai-at-ieor/23m1508/Shivam_23M1508/Interspeech/data/audio_set_2_chunks/french/chunk_1/0021-0021_001_phone-O1-000026-000603.wav"

# %%
"0021-0021_001_phone-O1-000026-000603"
# Out:
# '0021-0021_001_phone-O1-000026-000603'

# %%
original_text = "Collection de voix du projet Z Y deux-mille-vingt-et-un zéro sept trente, je suis l'enregistreur un."

# %%
multilingual_pretrained_asr(MODEL_ID_FRENCH, french_audio_path, device = device)
# Out:
# ['collections de voie du projet zady grec deux mille vingt-et unz zéro sept trente je suis lenregistrern']

# %% [markdown]
# ## Loading the german audio

# %%
german_audio_path = "/home/IITB/ai-at-ieor/23m1508/Shivam_23M1508/Interspeech/data/audio_set_2_chunks/german/chunk_1/0021-0021_001_phone-O1-002140-002337.wav"

original_text = "Ja, Schatz, was essen wir denn heute Abend?"

# %%
multilingual_pretrained_asr(MODEL_ID_GERMAN, german_audio_path, device = device)
# Out:
# ['ja schatz was esst man denn heute abend']

# %% [markdown]
# ## Loading the italian audio

# %%
italian_audio_path = "/home/IITB/ai-at-ieor/23m1508/Shivam_23M1508/Interspeech/data/audio_set_2_chunks/italian/chunk_1/0002-0002_003_phone-O1-002346-002637.wav"

original_text = "OK, ci ci sei Andrea?"

# %%
multilingual_pretrained_asr(MODEL_ID_ITALIAN, italian_audio_path, device = device)
# Out:
# ['okai ci sai andrea']

# %% [markdown]
# ## Loading the japnese audio

# %% [markdown]
# ### Checking the embedding size of facebook/wav2vec2-xls-r-1b model

# %%
import json
import csv
import re
import os
import torch
import random
import torchaudio
import torch.nn as nn
import numpy as np
import pandas as pd
from jiwer import wer
from tqdm.auto import tqdm
import torch.nn.functional as F
from IPython.display import Audio
from functools import partial
from torch.utils.data import Dataset

from transformers import Wav2Vec2Model
import torch.nn as nn
from torch.utils.data import DataLoader
# AdamW is best optimizer
from torch.optim import AdamW
from transformers import get_scheduler
from transformers import Wav2Vec2Model,Wav2Vec2Processor, Wav2Vec2FeatureExtractor

# %%
model_path = "facebook/wav2vec2-xls-r-1b"

# %%
device = "cuda:0" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cuda:0'

# %%
model = Wav2Vec2Model.from_pretrained(model_path)

# %%
model = model.to(device)

# %%
feature_extractor = Wav2Vec2FeatureExtractor(feature_size = 1, 
                                             sampling_rate = 16000, 
                                             padding_value = 0.0, 
                                             do_normalize = True, 
                                             return_attention_mask = True)

# %%
waveform, sr = torchaudio.load('/scratch/IITB/ai-at-ieor/23m1508/23m1508_backup/audio_set_2_chunks/german/chunk_1/0021-0021_001_phone-O1-002140-002337.wav')

# %%
waveform
# Out:
# tensor([[ 0.0010,  0.0015,  0.0016,  ..., -0.0055, -0.0059, -0.0067]])

# %%
input_values = feature_extractor(
                                waveform, sampling_rate=16000,return_tensors="pt"
                                )["input_values"].squeeze(0)

# %%
input_values = input_values.to(device)

# %%
out = model(input_values)

# %%
out['last_hidden_state'].shape
# Out:
# torch.Size([1, 98, 1280])

# %%
import torch

# %%
checkpoint_path = "/scratch/IITB/ai-at-ieor/23m1508/23m1508_backup/checkpoints_mtp/w_till_epoch_1/w_till_epoch_2/multilingual_asr_model_1130000_1150000.pt"

# %%
checkpoint = torch.load(checkpoint_path, map_location = 'cpu', weights_only = False)

# %%
from transformers import Wav2Vec2Model

# %%
# Loaidng the pretrained model
model = Wav2Vec2Model.from_pretrained("facebook/wav2vec2-xls-r-2b")

# %%
state_dict_keys = list(model.state_dict().keys())

# %%
state_dict_keys
# Out:
# ['masked_spec_embed',
#  'feature_extractor.conv_layers.0.conv.weight',
#  'feature_extractor.conv_layers.0.conv.bias',
#  'feature_extractor.conv_layers.0.layer_norm.weight',
#  'feature_extractor.conv_layers.0.layer_norm.bias',
#  'feature_extractor.conv_layers.1.conv.weight',
#  'feature_extractor.conv_layers.1.conv.bias',
#  'feature_extractor.conv_layers.1.layer_norm.weight',
#  'feature_extractor.conv_layers.1.layer_norm.bias',
#  'feature_extractor.conv_layers.2.conv.weight',
#  'feature_extractor.conv_layers.2.conv.bias',
#  'feature_extractor.conv_layers.2.layer_norm.weight',
#  'feature_extractor.conv_layers.2.layer_norm.bias',
#  'feature_extractor.conv_layers.3.conv.weight',
#  'feature_extractor.conv_layers.3.conv.bias',
#  'feature_extractor.conv_layers.3.layer_norm.weight',
#  'feature_extractor.conv_layers.3.layer_norm.bias',
#  'feature_extractor.conv_layers.4.conv.weight',
#  'feature_extractor.conv_layers.4.conv.bias',
#  'feature_extractor.conv_layers.4.layer_norm.weight',
#  'feature_extractor.conv_layers.4.layer_norm.bias',
#  'feature_extractor.conv_layers.5.conv.weight',
#  'feature_extractor.conv_layers.5.conv.bias',
#  'feature_extractor.conv_layers.5.layer_norm.weight',
#  'feature_extractor.conv_layers.5.layer_norm.bias',
#  'feature_extractor.conv_layers.6.conv.weight',
#  'feature_extractor.conv_layers.6.conv.bias',
#  'feature_extractor.conv_layers.6.layer_norm.weight',
#  'feature_extractor.conv_layers.6.layer_norm.bias',
#  'feature_projection.layer_norm.weight',
#  'feature_projection.layer_norm.bias',
#  'feature_projection.projection.weight',
#  'feature_projection.projection.bias',
#  'encoder.pos_conv_embed.conv.bias',
#  'encoder.pos_conv_embed.conv.parametrizations.weight.original0',
#  'encoder.pos_conv_embed.conv.parametrizations.weight.original1',
#  'encoder.layer_norm.weight',
#  'encoder.layer_norm.bias',
#  'encoder.layers.0.attention.k_proj.weight',
#  'encoder.layers.0.attention.k_proj.bias',
#  'encoder.layers.0.attention.v_proj.weight',
#  'encoder.layers.0.attention.v_proj.bias',
#  'encoder.layers.0.attention.q_proj.weight',
#  'encoder.layers.0.attention.q_proj.bias',
#  'encoder.layers.0.attention.out_proj.weight',
#  'encoder.layers.0.attention.out_proj.bias',
#  'encoder.layers.0.layer_norm.weight',
#  'encoder.layers.0.layer_norm.bias',
#  'encoder.layers.0.feed_forward.intermediate_dense.weight',
#  'encoder.layers.0.feed_forward.intermediate_dense.bias',
#  'encoder.layers.0.feed_forward.output_dense.weight',
#  'encoder.layers.0.feed_forward.output_dense.bias',
#  'encoder.layers.0.final_layer_norm.weight',
#  'encoder.layers.0.final_layer_norm.bias',
#  'encoder.layers.1.attention.k_proj.weight',
#  'encoder.layers.1.attention.k_proj.bias',
#  'encoder.layers.1.attention.v_proj.weight',
#  'encoder.layers.1.attention.v_proj.bias',
#  'encoder.layers.1.attention.q_proj.weight',
#  'encoder.layers.1.attention.q_proj.bias',
#  'encoder.layers.1.attention.out_proj.weight',
#  'encoder.layers.1.attention.out_proj.bias',
#  'encoder.layers.1.layer_norm.weight',
#  'encoder.layers.1.layer_norm.bias',
#  'encoder.layers.1.feed_forward.intermediate_dense.weight',
#  'encoder.layers.1.feed_forward.intermediate_dense.bias',
#  'encoder.layers.1.feed_forward.output_dense.weight',
#  'encoder.layers.1.feed_forward.output_dense.bias',
#  'encoder.layers.1.final_layer_norm.weight',
#  'encoder.layers.1.final_layer_norm.bias',
#  'encoder.layers.2.attention.k_proj.weight',
#  'encoder.layers.2.attention.k_proj.bias',
#  'encoder.layers.2.attention.v_proj.weight',
#  'encoder.layers.2.attention.v_proj.bias',
#  'encoder.layers.2.attention.q_proj.weight',
#  'encoder.layers.2.attention.q_proj.bias',
#  'encoder.layers.2.attention.out_proj.weight',
#  'encoder.layers.2.attention.out_proj.bias',
#  'encoder.layers.2.layer_norm.weight',
#  'encoder.layers.2.layer_norm.bias',
#  'encoder.layers.2.feed_forward.intermediate_dense.weight',
#  'encoder.layers.2.feed_forward.intermediate_dense.bias',
#  'encoder.layers.2.feed_forward.output_dense.weight',
#  'encoder.layers.2.feed_forward.output_dense.bias',
#  'encoder.layers.2.final_layer_norm.weight',
#  'encoder.layers.2.final_layer_norm.bias',
#  'encoder.layers.3.attention.k_proj.weight',
#  'encoder.layers.3.attention.k_proj.bias',
#  'encoder.layers.3.attention.v_proj.weight',
#  'encoder.layers.3.attention.v_proj.bias',
#  'encoder.layers.3.attention.q_proj.weight',
#  'encoder.layers.3.attention.q_proj.bias',
#  'encoder.layers.3.attention.out_proj.weight',
#  'encoder.layers.3.attention.out_proj.bias',
#  'encoder.layers.3.layer_norm.weight',
#  'encoder.layers.3.layer_norm.bias',
#  'encoder.layers.3.feed_forward.intermediate_dense.weight',
#  'encoder.layers.3.feed_forward.intermediate_dense.bias',
#  'encoder.layers.3.feed_forward.output_dense.weight',
#  'encoder.layers.3.feed_forward.output_dense.bias',
#  'encoder.layers.3.final_layer_norm.weight',
#  'encoder.layers.3.final_layer_norm.bias',
#  'encoder.layers.4.attention.k_proj.weight',
#  'encoder.layers.4.attention.k_proj.bias',
#  'encoder.layers.4.attention.v_proj.weight',
#  'encoder.layers.4.attention.v_proj.bias',
#  'encoder.layers.4.attention.q_proj.weight',
#  'encoder.layers.4.attention.q_proj.bias',
#  'encoder.layers.4.attention.out_proj.weight',
#  'encoder.layers.4.attention.out_proj.bias',
#  'encoder.layers.4.layer_norm.weight',
#  'encoder.layers.4.layer_norm.bias',
#  'encoder.layers.4.feed_forward.intermediate_dense.weight',
#  'encoder.layers.4.feed_forward.intermediate_dense.bias',
#  'encoder.layers.4.feed_forward.output_dense.weight',
#  'encoder.layers.4.feed_forward.output_dense.bias',
#  'encoder.layers.4.final_layer_norm.weight',
#  'encoder.layers.4.final_layer_norm.bias',
#  'encoder.layers.5.attention.k_proj.weight',
#  'encoder.layers.5.attention.k_proj.bias',
#  'encoder.layers.5.attention.v_proj.weight',
#  'encoder.layers.5.attention.v_proj.bias',
#  'encoder.layers.5.attention.q_proj.weight',
#  'encoder.layers.5.attention.q_proj.bias',
#  'encoder.layers.5.attention.out_proj.weight',
#  'encoder.layers.5.attention.out_proj.bias',
#  'encoder.layers.5.layer_norm.weight',
#  'encoder.layers.5.layer_norm.bias',
#  'encoder.layers.5.feed_forward.intermediate_dense.weight',
#  'encoder.layers.5.feed_forward.intermediate_dense.bias',
#  'encoder.layers.5.feed_forward.output_dense.weight',
#  'encoder.layers.5.feed_forward.output_dense.bias',
#  'encoder.layers.5.final_layer_norm.weight',
#  'encoder.layers.5.final_layer_norm.bias',
#  'encoder.layers.6.attention.k_proj.weight',
#  'encoder.layers.6.attention.k_proj.bias',
#  'encoder.layers.6.attention.v_proj.weight',
#  'encoder.layers.6.attention.v_proj.bias',
#  'encoder.layers.6.attention.q_proj.weight',
#  'encoder.layers.6.attention.q_proj.bias',
#  'encoder.layers.6.attention.out_proj.weight',
#  'encoder.layers.6.attention.out_proj.bias',
#  'encoder.layers.6.layer_norm.weight',
#  'encoder.layers.6.layer_norm.bias',
#  'encoder.layers.6.feed_forward.intermediate_dense.weight',
#  'encoder.layers.6.feed_forward.intermediate_dense.bias',
#  'encoder.layers.6.feed_forward.output_dense.weight',
#  'encoder.layers.6.feed_forward.output_dense.bias',
#  'encoder.layers.6.final_layer_norm.weight',
#  'encoder.layers.6.final_layer_norm.bias',
#  'encoder.layers.7.attention.k_proj.weight',
#  'encoder.layers.7.attention.k_proj.bias',
#  'encoder.layers.7.attention.v_proj.weight',
#  'encoder.layers.7.attention.v_proj.bias',
#  'encoder.layers.7.attention.q_proj.weight',
#  'encoder.layers.7.attention.q_proj.bias',
#  'encoder.layers.7.attention.out_proj.weight',
#  'encoder.layers.7.attention.out_proj.bias',
#  'encoder.layers.7.layer_norm.weight',
#  'encoder.layers.7.layer_norm.bias',
#  'encoder.layers.7.feed_forward.intermediate_dense.weight',
#  'encoder.layers.7.feed_forward.intermediate_dense.bias',
#  'encoder.layers.7.feed_forward.output_dense.weight',
#  'encoder.layers.7.feed_forward.output_dense.bias',
#  'encoder.layers.7.final_layer_norm.weight',
#  'encoder.layers.7.final_layer_norm.bias',
#  'encoder.layers.8.attention.k_proj.weight',
#  'encoder.layers.8.attention.k_proj.bias',
#  'encoder.layers.8.attention.v_proj.weight',
#  'encoder.layers.8.attention.v_proj.bias',
#  'encoder.layers.8.attention.q_proj.weight',
#  'encoder.layers.8.attention.q_proj.bias',
#  'encoder.layers.8.attention.out_proj.weight',
#  'encoder.layers.8.attention.out_proj.bias',
#  'encoder.layers.8.layer_norm.weight',
#  'encoder.layers.8.layer_norm.bias',
#  'encoder.layers.8.feed_forward.intermediate_dense.weight',
#  'encoder.layers.8.feed_forward.intermediate_dense.bias',
#  'encoder.layers.8.feed_forward.output_dense.weight',
#  'encoder.layers.8.feed_forward.output_dense.bias',
#  'encoder.layers.8.final_layer_norm.weight',
#  'encoder.layers.8.final_layer_norm.bias',
#  'encoder.layers.9.attention.k_proj.weight',
#  'encoder.layers.9.attention.k_proj.bias',
#  'encoder.layers.9.attention.v_proj.weight',
#  'encoder.layers.9.attention.v_proj.bias',
#  'encoder.layers.9.attention.q_proj.weight',
#  'encoder.layers.9.attention.q_proj.bias',
#  'encoder.layers.9.attention.out_proj.weight',
#  'encoder.layers.9.attention.out_proj.bias',
#  'encoder.layers.9.layer_norm.weight',
#  'encoder.layers.9.layer_norm.bias',
#  'encoder.layers.9.feed_forward.intermediate_dense.weight',
#  'encoder.layers.9.feed_forward.intermediate_dense.bias',
#  'encoder.layers.9.feed_forward.output_dense.weight',
#  'encoder.layers.9.feed_forward.output_dense.bias',
#  'encoder.layers.9.final_layer_norm.weight',
#  'encoder.layers.9.final_layer_norm.bias',
#  'encoder.layers.10.attention.k_proj.weight',
#  'encoder.layers.10.attention.k_proj.bias',
#  'encoder.layers.10.attention.v_proj.weight',
#  'encoder.layers.10.attention.v_proj.bias',
#  'encoder.layers.10.attention.q_proj.weight',
#  'encoder.layers.10.attention.q_proj.bias',
#  'encoder.layers.10.attention.out_proj.weight',
#  'encoder.layers.10.attention.out_proj.bias',
#  'encoder.layers.10.layer_norm.weight',
#  'encoder.layers.10.layer_norm.bias',
#  'encoder.layers.10.feed_forward.intermediate_dense.weight',
#  'encoder.layers.10.feed_forward.intermediate_dense.bias',
#  'encoder.layers.10.feed_forward.output_dense.weight',
#  'encoder.layers.10.feed_forward.output_dense.bias',
#  'encoder.layers.10.final_layer_norm.weight',
#  'encoder.layers.10.final_layer_norm.bias',
#  'encoder.layers.11.attention.k_proj.weight',
#  'encoder.layers.11.attention.k_proj.bias',
#  'encoder.layers.11.attention.v_proj.weight',
#  'encoder.layers.11.attention.v_proj.bias',
#  'encoder.layers.11.attention.q_proj.weight',
#  'encoder.layers.11.attention.q_proj.bias',
#  'encoder.layers.11.attention.out_proj.weight',
#  'encoder.layers.11.attention.out_proj.bias',
#  'encoder.layers.11.layer_norm.weight',
#  'encoder.layers.11.layer_norm.bias',
#  'encoder.layers.11.feed_forward.intermediate_dense.weight',
#  'encoder.layers.11.feed_forward.intermediate_dense.bias',
#  'encoder.layers.11.feed_forward.output_dense.weight',
#  'encoder.layers.11.feed_forward.output_dense.bias',
#  'encoder.layers.11.final_layer_norm.weight',
#  'encoder.layers.11.final_layer_norm.bias',
#  'encoder.layers.12.attention.k_proj.weight',
#  'encoder.layers.12.attention.k_proj.bias',
#  'encoder.layers.12.attention.v_proj.weight',
#  'encoder.layers.12.attention.v_proj.bias',
#  'encoder.layers.12.attention.q_proj.weight',
#  'encoder.layers.12.attention.q_proj.bias',
#  'encoder.layers.12.attention.out_proj.weight',
#  'encoder.layers.12.attention.out_proj.bias',
#  'encoder.layers.12.layer_norm.weight',
#  'encoder.layers.12.layer_norm.bias',
#  'encoder.layers.12.feed_forward.intermediate_dense.weight',
#  'encoder.layers.12.feed_forward.intermediate_dense.bias',
#  'encoder.layers.12.feed_forward.output_dense.weight',
#  'encoder.layers.12.feed_forward.output_dense.bias',
#  'encoder.layers.12.final_layer_norm.weight',
#  'encoder.layers.12.final_layer_norm.bias',
#  'encoder.layers.13.attention.k_proj.weight',
#  'encoder.layers.13.attention.k_proj.bias',
#  'encoder.layers.13.attention.v_proj.weight',
#  'encoder.layers.13.attention.v_proj.bias',
#  'encoder.layers.13.attention.q_proj.weight',
#  'encoder.layers.13.attention.q_proj.bias',
#  'encoder.layers.13.attention.out_proj.weight',
#  'encoder.layers.13.attention.out_proj.bias',
#  'encoder.layers.13.layer_norm.weight',
#  'encoder.layers.13.layer_norm.bias',
#  'encoder.layers.13.feed_forward.intermediate_dense.weight',
#  'encoder.layers.13.feed_forward.intermediate_dense.bias',
#  'encoder.layers.13.feed_forward.output_dense.weight',
#  'encoder.layers.13.feed_forward.output_dense.bias',
#  'encoder.layers.13.final_layer_norm.weight',
#  'encoder.layers.13.final_layer_norm.bias',
#  'encoder.layers.14.attention.k_proj.weight',
#  'encoder.layers.14.attention.k_proj.bias',
#  'encoder.layers.14.attention.v_proj.weight',
#  'encoder.layers.14.attention.v_proj.bias',
#  'encoder.layers.14.attention.q_proj.weight',
#  'encoder.layers.14.attention.q_proj.bias',
#  'encoder.layers.14.attention.out_proj.weight',
#  'encoder.layers.14.attention.out_proj.bias',
#  'encoder.layers.14.layer_norm.weight',
#  'encoder.layers.14.layer_norm.bias',
#  'encoder.layers.14.feed_forward.intermediate_dense.weight',
#  'encoder.layers.14.feed_forward.intermediate_dense.bias',
#  'encoder.layers.14.feed_forward.output_dense.weight',
#  'encoder.layers.14.feed_forward.output_dense.bias',
#  'encoder.layers.14.final_layer_norm.weight',
#  'encoder.layers.14.final_layer_norm.bias',
#  'encoder.layers.15.attention.k_proj.weight',
#  'encoder.layers.15.attention.k_proj.bias',
#  'encoder.layers.15.attention.v_proj.weight',
#  'encoder.layers.15.attention.v_proj.bias',
#  'encoder.layers.15.attention.q_proj.weight',
#  'encoder.layers.15.attention.q_proj.bias',
#  'encoder.layers.15.attention.out_proj.weight',
#  'encoder.layers.15.attention.out_proj.bias',
#  'encoder.layers.15.layer_norm.weight',
#  'encoder.layers.15.layer_norm.bias',
#  'encoder.layers.15.feed_forward.intermediate_dense.weight',
#  'encoder.layers.15.feed_forward.intermediate_dense.bias',
#  'encoder.layers.15.feed_forward.output_dense.weight',
#  'encoder.layers.15.feed_forward.output_dense.bias',
#  'encoder.layers.15.final_layer_norm.weight',
#  'encoder.layers.15.final_layer_norm.bias',
#  'encoder.layers.16.attention.k_proj.weight',
#  'encoder.layers.16.attention.k_proj.bias',
#  'encoder.layers.16.attention.v_proj.weight',
#  'encoder.layers.16.attention.v_proj.bias',
#  'encoder.layers.16.attention.q_proj.weight',
#  'encoder.layers.16.attention.q_proj.bias',
#  'encoder.layers.16.attention.out_proj.weight',
#  'encoder.layers.16.attention.out_proj.bias',
#  'encoder.layers.16.layer_norm.weight',
#  'encoder.layers.16.layer_norm.bias',
#  'encoder.layers.16.feed_forward.intermediate_dense.weight',
#  'encoder.layers.16.feed_forward.intermediate_dense.bias',
#  'encoder.layers.16.feed_forward.output_dense.weight',
#  'encoder.layers.16.feed_forward.output_dense.bias',
#  'encoder.layers.16.final_layer_norm.weight',
#  'encoder.layers.16.final_layer_norm.bias',
#  'encoder.layers.17.attention.k_proj.weight',
#  'encoder.layers.17.attention.k_proj.bias',
#  'encoder.layers.17.attention.v_proj.weight',
#  'encoder.layers.17.attention.v_proj.bias',
#  'encoder.layers.17.attention.q_proj.weight',
#  'encoder.layers.17.attention.q_proj.bias',
#  'encoder.layers.17.attention.out_proj.weight',
#  'encoder.layers.17.attention.out_proj.bias',
#  'encoder.layers.17.layer_norm.weight',
#  'encoder.layers.17.layer_norm.bias',
#  'encoder.layers.17.feed_forward.intermediate_dense.weight',
#  'encoder.layers.17.feed_forward.intermediate_dense.bias',
#  'encoder.layers.17.feed_forward.output_dense.weight',
#  'encoder.layers.17.feed_forward.output_dense.bias',
#  'encoder.layers.17.final_layer_norm.weight',
#  'encoder.layers.17.final_layer_norm.bias',
#  'encoder.layers.18.attention.k_proj.weight',
#  'encoder.layers.18.attention.k_proj.bias',
#  'encoder.layers.18.attention.v_proj.weight',
#  'encoder.layers.18.attention.v_proj.bias',
#  'encoder.layers.18.attention.q_proj.weight',
#  'encoder.layers.18.attention.q_proj.bias',
#  'encoder.layers.18.attention.out_proj.weight',
#  'encoder.layers.18.attention.out_proj.bias',
#  'encoder.layers.18.layer_norm.weight',
#  'encoder.layers.18.layer_norm.bias',
#  'encoder.layers.18.feed_forward.intermediate_dense.weight',
#  'encoder.layers.18.feed_forward.intermediate_dense.bias',
#  'encoder.layers.18.feed_forward.output_dense.weight',
#  'encoder.layers.18.feed_forward.output_dense.bias',
#  'encoder.layers.18.final_layer_norm.weight',
#  'encoder.layers.18.final_layer_norm.bias',
#  'encoder.layers.19.attention.k_proj.weight',
#  'encoder.layers.19.attention.k_proj.bias',
#  'encoder.layers.19.attention.v_proj.weight',
#  'encoder.layers.19.attention.v_proj.bias',
#  'encoder.layers.19.attention.q_proj.weight',
#  'encoder.layers.19.attention.q_proj.bias',
#  'encoder.layers.19.attention.out_proj.weight',
#  'encoder.layers.19.attention.out_proj.bias',
#  'encoder.layers.19.layer_norm.weight',
#  'encoder.layers.19.layer_norm.bias',
#  'encoder.layers.19.feed_forward.intermediate_dense.weight',
#  'encoder.layers.19.feed_forward.intermediate_dense.bias',
#  'encoder.layers.19.feed_forward.output_dense.weight',
#  'encoder.layers.19.feed_forward.output_dense.bias',
#  'encoder.layers.19.final_layer_norm.weight',
#  'encoder.layers.19.final_layer_norm.bias',
#  'encoder.layers.20.attention.k_proj.weight',
#  'encoder.layers.20.attention.k_proj.bias',
#  'encoder.layers.20.attention.v_proj.weight',
#  'encoder.layers.20.attention.v_proj.bias',
#  'encoder.layers.20.attention.q_proj.weight',
#  'encoder.layers.20.attention.q_proj.bias',
#  'encoder.layers.20.attention.out_proj.weight',
#  'encoder.layers.20.attention.out_proj.bias',
#  'encoder.layers.20.layer_norm.weight',
#  'encoder.layers.20.layer_norm.bias',
#  'encoder.layers.20.feed_forward.intermediate_dense.weight',
#  'encoder.layers.20.feed_forward.intermediate_dense.bias',
#  'encoder.layers.20.feed_forward.output_dense.weight',
#  'encoder.layers.20.feed_forward.output_dense.bias',
#  'encoder.layers.20.final_layer_norm.weight',
#  'encoder.layers.20.final_layer_norm.bias',
#  'encoder.layers.21.attention.k_proj.weight',
#  'encoder.layers.21.attention.k_proj.bias',
#  'encoder.layers.21.attention.v_proj.weight',
#  'encoder.layers.21.attention.v_proj.bias',
#  'encoder.layers.21.attention.q_proj.weight',
#  'encoder.layers.21.attention.q_proj.bias',
#  'encoder.layers.21.attention.out_proj.weight',
#  'encoder.layers.21.attention.out_proj.bias',
#  'encoder.layers.21.layer_norm.weight',
#  'encoder.layers.21.layer_norm.bias',
#  'encoder.layers.21.feed_forward.intermediate_dense.weight',
#  'encoder.layers.21.feed_forward.intermediate_dense.bias',
#  'encoder.layers.21.feed_forward.output_dense.weight',
#  'encoder.layers.21.feed_forward.output_dense.bias',
#  'encoder.layers.21.final_layer_norm.weight',
#  'encoder.layers.21.final_layer_norm.bias',
#  'encoder.layers.22.attention.k_proj.weight',
#  'encoder.layers.22.attention.k_proj.bias',
#  'encoder.layers.22.attention.v_proj.weight',
#  'encoder.layers.22.attention.v_proj.bias',
#  'encoder.layers.22.attention.q_proj.weight',
#  'encoder.layers.22.attention.q_proj.bias',
#  'encoder.layers.22.attention.out_proj.weight',
#  'encoder.layers.22.attention.out_proj.bias',
#  'encoder.layers.22.layer_norm.weight',
#  'encoder.layers.22.layer_norm.bias',
#  'encoder.layers.22.feed_forward.intermediate_dense.weight',
#  'encoder.layers.22.feed_forward.intermediate_dense.bias',
#  'encoder.layers.22.feed_forward.output_dense.weight',
#  'encoder.layers.22.feed_forward.output_dense.bias',
#  'encoder.layers.22.final_layer_norm.weight',
#  'encoder.layers.22.final_layer_norm.bias',
#  'encoder.layers.23.attention.k_proj.weight',
#  'encoder.layers.23.attention.k_proj.bias',
#  'encoder.layers.23.attention.v_proj.weight',
#  'encoder.layers.23.attention.v_proj.bias',
#  'encoder.layers.23.attention.q_proj.weight',
#  'encoder.layers.23.attention.q_proj.bias',
#  'encoder.layers.23.attention.out_proj.weight',
#  'encoder.layers.23.attention.out_proj.bias',
#  'encoder.layers.23.layer_norm.weight',
#  'encoder.layers.23.layer_norm.bias',
#  'encoder.layers.23.feed_forward.intermediate_dense.weight',
#  'encoder.layers.23.feed_forward.intermediate_dense.bias',
#  'encoder.layers.23.feed_forward.output_dense.weight',
#  'encoder.layers.23.feed_forward.output_dense.bias',
#  'encoder.layers.23.final_layer_norm.weight',
#  'encoder.layers.23.final_layer_norm.bias',
#  'encoder.layers.24.attention.k_proj.weight',
#  'encoder.layers.24.attention.k_proj.bias',
#  'encoder.layers.24.attention.v_proj.weight',
#  'encoder.layers.24.attention.v_proj.bias',
#  'encoder.layers.24.attention.q_proj.weight',
#  'encoder.layers.24.attention.q_proj.bias',
#  'encoder.layers.24.attention.out_proj.weight',
#  'encoder.layers.24.attention.out_proj.bias',
#  'encoder.layers.24.layer_norm.weight',
#  'encoder.layers.24.layer_norm.bias',
#  'encoder.layers.24.feed_forward.intermediate_dense.weight',
#  'encoder.layers.24.feed_forward.intermediate_dense.bias',
#  'encoder.layers.24.feed_forward.output_dense.weight',
#  'encoder.layers.24.feed_forward.output_dense.bias',
#  'encoder.layers.24.final_layer_norm.weight',
#  'encoder.layers.24.final_layer_norm.bias',
#  'encoder.layers.25.attention.k_proj.weight',
#  'encoder.layers.25.attention.k_proj.bias',
#  'encoder.layers.25.attention.v_proj.weight',
#  'encoder.layers.25.attention.v_proj.bias',
#  'encoder.layers.25.attention.q_proj.weight',
#  'encoder.layers.25.attention.q_proj.bias',
#  'encoder.layers.25.attention.out_proj.weight',
#  'encoder.layers.25.attention.out_proj.bias',
#  'encoder.layers.25.layer_norm.weight',
#  'encoder.layers.25.layer_norm.bias',
#  'encoder.layers.25.feed_forward.intermediate_dense.weight',
#  'encoder.layers.25.feed_forward.intermediate_dense.bias',
#  'encoder.layers.25.feed_forward.output_dense.weight',
#  'encoder.layers.25.feed_forward.output_dense.bias',
#  'encoder.layers.25.final_layer_norm.weight',
#  'encoder.layers.25.final_layer_norm.bias',
#  'encoder.layers.26.attention.k_proj.weight',
#  'encoder.layers.26.attention.k_proj.bias',
#  'encoder.layers.26.attention.v_proj.weight',
#  'encoder.layers.26.attention.v_proj.bias',
#  'encoder.layers.26.attention.q_proj.weight',
#  'encoder.layers.26.attention.q_proj.bias',
#  'encoder.layers.26.attention.out_proj.weight',
#  'encoder.layers.26.attention.out_proj.bias',
#  'encoder.layers.26.layer_norm.weight',
#  'encoder.layers.26.layer_norm.bias',
#  'encoder.layers.26.feed_forward.intermediate_dense.weight',
#  'encoder.layers.26.feed_forward.intermediate_dense.bias',
#  'encoder.layers.26.feed_forward.output_dense.weight',
#  'encoder.layers.26.feed_forward.output_dense.bias',
#  'encoder.layers.26.final_layer_norm.weight',
#  'encoder.layers.26.final_layer_norm.bias',
#  'encoder.layers.27.attention.k_proj.weight',
#  'encoder.layers.27.attention.k_proj.bias',
#  'encoder.layers.27.attention.v_proj.weight',
#  'encoder.layers.27.attention.v_proj.bias',
#  'encoder.layers.27.attention.q_proj.weight',
#  'encoder.layers.27.attention.q_proj.bias',
#  'encoder.layers.27.attention.out_proj.weight',
#  'encoder.layers.27.attention.out_proj.bias',
#  'encoder.layers.27.layer_norm.weight',
#  'encoder.layers.27.layer_norm.bias',
#  'encoder.layers.27.feed_forward.intermediate_dense.weight',
#  'encoder.layers.27.feed_forward.intermediate_dense.bias',
#  'encoder.layers.27.feed_forward.output_dense.weight',
#  'encoder.layers.27.feed_forward.output_dense.bias',
#  'encoder.layers.27.final_layer_norm.weight',
#  'encoder.layers.27.final_layer_norm.bias',
#  'encoder.layers.28.attention.k_proj.weight',
#  'encoder.layers.28.attention.k_proj.bias',
#  'encoder.layers.28.attention.v_proj.weight',
#  'encoder.layers.28.attention.v_proj.bias',
#  'encoder.layers.28.attention.q_proj.weight',
#  'encoder.layers.28.attention.q_proj.bias',
#  'encoder.layers.28.attention.out_proj.weight',
#  'encoder.layers.28.attention.out_proj.bias',
#  'encoder.layers.28.layer_norm.weight',
#  'encoder.layers.28.layer_norm.bias',
#  'encoder.layers.28.feed_forward.intermediate_dense.weight',
#  'encoder.layers.28.feed_forward.intermediate_dense.bias',
#  'encoder.layers.28.feed_forward.output_dense.weight',
#  'encoder.layers.28.feed_forward.output_dense.bias',
#  'encoder.layers.28.final_layer_norm.weight',
#  'encoder.layers.28.final_layer_norm.bias',
#  'encoder.layers.29.attention.k_proj.weight',
#  'encoder.layers.29.attention.k_proj.bias',
#  'encoder.layers.29.attention.v_proj.weight',
#  'encoder.layers.29.attention.v_proj.bias',
#  'encoder.layers.29.attention.q_proj.weight',
#  'encoder.layers.29.attention.q_proj.bias',
#  'encoder.layers.29.attention.out_proj.weight',
#  'encoder.layers.29.attention.out_proj.bias',
#  'encoder.layers.29.layer_norm.weight',
#  'encoder.layers.29.layer_norm.bias',
#  'encoder.layers.29.feed_forward.intermediate_dense.weight',
#  'encoder.layers.29.feed_forward.intermediate_dense.bias',
#  'encoder.layers.29.feed_forward.output_dense.weight',
#  'encoder.layers.29.feed_forward.output_dense.bias',
#  'encoder.layers.29.final_layer_norm.weight',
#  'encoder.layers.29.final_layer_norm.bias',
#  'encoder.layers.30.attention.k_proj.weight',
#  'encoder.layers.30.attention.k_proj.bias',
#  'encoder.layers.30.attention.v_proj.weight',
#  'encoder.layers.30.attention.v_proj.bias',
#  'encoder.layers.30.attention.q_proj.weight',
#  'encoder.layers.30.attention.q_proj.bias',
#  'encoder.layers.30.attention.out_proj.weight',
#  'encoder.layers.30.attention.out_proj.bias',
#  'encoder.layers.30.layer_norm.weight',
#  'encoder.layers.30.layer_norm.bias',
#  'encoder.layers.30.feed_forward.intermediate_dense.weight',
#  'encoder.layers.30.feed_forward.intermediate_dense.bias',
#  'encoder.layers.30.feed_forward.output_dense.weight',
#  'encoder.layers.30.feed_forward.output_dense.bias',
#  'encoder.layers.30.final_layer_norm.weight',
#  'encoder.layers.30.final_layer_norm.bias',
#  'encoder.layers.31.attention.k_proj.weight',
#  'encoder.layers.31.attention.k_proj.bias',
#  'encoder.layers.31.attention.v_proj.weight',
#  'encoder.layers.31.attention.v_proj.bias',
#  'encoder.layers.31.attention.q_proj.weight',
#  'encoder.layers.31.attention.q_proj.bias',
#  'encoder.layers.31.attention.out_proj.weight',
#  'encoder.layers.31.attention.out_proj.bias',
#  'encoder.layers.31.layer_norm.weight',
#  'encoder.layers.31.layer_norm.bias',
#  'encoder.layers.31.feed_forward.intermediate_dense.weight',
#  'encoder.layers.31.feed_forward.intermediate_dense.bias',
#  'encoder.layers.31.feed_forward.output_dense.weight',
#  'encoder.layers.31.feed_forward.output_dense.bias',
#  'encoder.layers.31.final_layer_norm.weight',
#  'encoder.layers.31.final_layer_norm.bias',
#  'encoder.layers.32.attention.k_proj.weight',
#  'encoder.layers.32.attention.k_proj.bias',
#  'encoder.layers.32.attention.v_proj.weight',
#  'encoder.layers.32.attention.v_proj.bias',
#  'encoder.layers.32.attention.q_proj.weight',
#  'encoder.layers.32.attention.q_proj.bias',
#  'encoder.layers.32.attention.out_proj.weight',
#  'encoder.layers.32.attention.out_proj.bias',
#  'encoder.layers.32.layer_norm.weight',
#  'encoder.layers.32.layer_norm.bias',
#  'encoder.layers.32.feed_forward.intermediate_dense.weight',
#  'encoder.layers.32.feed_forward.intermediate_dense.bias',
#  'encoder.layers.32.feed_forward.output_dense.weight',
#  'encoder.layers.32.feed_forward.output_dense.bias',
#  'encoder.layers.32.final_layer_norm.weight',
#  'encoder.layers.32.final_layer_norm.bias',
#  'encoder.layers.33.attention.k_proj.weight',
#  'encoder.layers.33.attention.k_proj.bias',
#  'encoder.layers.33.attention.v_proj.weight',
#  'encoder.layers.33.attention.v_proj.bias',
#  'encoder.layers.33.attention.q_proj.weight',
#  'encoder.layers.33.attention.q_proj.bias',
#  'encoder.layers.33.attention.out_proj.weight',
#  'encoder.layers.33.attention.out_proj.bias',
#  'encoder.layers.33.layer_norm.weight',
#  'encoder.layers.33.layer_norm.bias',
#  'encoder.layers.33.feed_forward.intermediate_dense.weight',
#  'encoder.layers.33.feed_forward.intermediate_dense.bias',
#  'encoder.layers.33.feed_forward.output_dense.weight',
#  'encoder.layers.33.feed_forward.output_dense.bias',
#  'encoder.layers.33.final_layer_norm.weight',
#  'encoder.layers.33.final_layer_norm.bias',
#  'encoder.layers.34.attention.k_proj.weight',
#  'encoder.layers.34.attention.k_proj.bias',
#  'encoder.layers.34.attention.v_proj.weight',
#  'encoder.layers.34.attention.v_proj.bias',
#  'encoder.layers.34.attention.q_proj.weight',
#  'encoder.layers.34.attention.q_proj.bias',
#  'encoder.layers.34.attention.out_proj.weight',
#  'encoder.layers.34.attention.out_proj.bias',
#  'encoder.layers.34.layer_norm.weight',
#  'encoder.layers.34.layer_norm.bias',
#  'encoder.layers.34.feed_forward.intermediate_dense.weight',
#  'encoder.layers.34.feed_forward.intermediate_dense.bias',
#  'encoder.layers.34.feed_forward.output_dense.weight',
#  'encoder.layers.34.feed_forward.output_dense.bias',
#  'encoder.layers.34.final_layer_norm.weight',
#  'encoder.layers.34.final_layer_norm.bias',
#  'encoder.layers.35.attention.k_proj.weight',
#  'encoder.layers.35.attention.k_proj.bias',
#  'encoder.layers.35.attention.v_proj.weight',
#  'encoder.layers.35.attention.v_proj.bias',
#  'encoder.layers.35.attention.q_proj.weight',
#  'encoder.layers.35.attention.q_proj.bias',
#  'encoder.layers.35.attention.out_proj.weight',
#  'encoder.layers.35.attention.out_proj.bias',
#  'encoder.layers.35.layer_norm.weight',
#  'encoder.layers.35.layer_norm.bias',
#  'encoder.layers.35.feed_forward.intermediate_dense.weight',
#  'encoder.layers.35.feed_forward.intermediate_dense.bias',
#  'encoder.layers.35.feed_forward.output_dense.weight',
#  'encoder.layers.35.feed_forward.output_dense.bias',
#  'encoder.layers.35.final_layer_norm.weight',
#  'encoder.layers.35.final_layer_norm.bias',
#  'encoder.layers.36.attention.k_proj.weight',
#  'encoder.layers.36.attention.k_proj.bias',
#  'encoder.layers.36.attention.v_proj.weight',
#  'encoder.layers.36.attention.v_proj.bias',
#  'encoder.layers.36.attention.q_proj.weight',
#  'encoder.layers.36.attention.q_proj.bias',
#  'encoder.layers.36.attention.out_proj.weight',
#  'encoder.layers.36.attention.out_proj.bias',
#  'encoder.layers.36.layer_norm.weight',
#  'encoder.layers.36.layer_norm.bias',
#  'encoder.layers.36.feed_forward.intermediate_dense.weight',
#  'encoder.layers.36.feed_forward.intermediate_dense.bias',
#  'encoder.layers.36.feed_forward.output_dense.weight',
#  'encoder.layers.36.feed_forward.output_dense.bias',
#  'encoder.layers.36.final_layer_norm.weight',
#  'encoder.layers.36.final_layer_norm.bias',
#  'encoder.layers.37.attention.k_proj.weight',
#  'encoder.layers.37.attention.k_proj.bias',
#  'encoder.layers.37.attention.v_proj.weight',
#  'encoder.layers.37.attention.v_proj.bias',
#  'encoder.layers.37.attention.q_proj.weight',
#  'encoder.layers.37.attention.q_proj.bias',
#  'encoder.layers.37.attention.out_proj.weight',
#  'encoder.layers.37.attention.out_proj.bias',
#  'encoder.layers.37.layer_norm.weight',
#  'encoder.layers.37.layer_norm.bias',
#  'encoder.layers.37.feed_forward.intermediate_dense.weight',
#  'encoder.layers.37.feed_forward.intermediate_dense.bias',
#  'encoder.layers.37.feed_forward.output_dense.weight',
#  'encoder.layers.37.feed_forward.output_dense.bias',
#  'encoder.layers.37.final_layer_norm.weight',
#  'encoder.layers.37.final_layer_norm.bias',
#  'encoder.layers.38.attention.k_proj.weight',
#  'encoder.layers.38.attention.k_proj.bias',
#  'encoder.layers.38.attention.v_proj.weight',
#  'encoder.layers.38.attention.v_proj.bias',
#  'encoder.layers.38.attention.q_proj.weight',
#  'encoder.layers.38.attention.q_proj.bias',
#  'encoder.layers.38.attention.out_proj.weight',
#  'encoder.layers.38.attention.out_proj.bias',
#  'encoder.layers.38.layer_norm.weight',
#  'encoder.layers.38.layer_norm.bias',
#  'encoder.layers.38.feed_forward.intermediate_dense.weight',
#  'encoder.layers.38.feed_forward.intermediate_dense.bias',
#  'encoder.layers.38.feed_forward.output_dense.weight',
#  'encoder.layers.38.feed_forward.output_dense.bias',
#  'encoder.layers.38.final_layer_norm.weight',
#  'encoder.layers.38.final_layer_norm.bias',
#  'encoder.layers.39.attention.k_proj.weight',
#  'encoder.layers.39.attention.k_proj.bias',
#  'encoder.layers.39.attention.v_proj.weight',
#  'encoder.layers.39.attention.v_proj.bias',
#  'encoder.layers.39.attention.q_proj.weight',
#  'encoder.layers.39.attention.q_proj.bias',
#  'encoder.layers.39.attention.out_proj.weight',
#  'encoder.layers.39.attention.out_proj.bias',
#  'encoder.layers.39.layer_norm.weight',
#  'encoder.layers.39.layer_norm.bias',
#  'encoder.layers.39.feed_forward.intermediate_dense.weight',
#  'encoder.layers.39.feed_forward.intermediate_dense.bias',
#  'encoder.layers.39.feed_forward.output_dense.weight',
#  'encoder.layers.39.feed_forward.output_dense.bias',
#  'encoder.layers.39.final_layer_norm.weight',
#  'encoder.layers.39.final_layer_norm.bias',
#  'encoder.layers.40.attention.k_proj.weight',
#  'encoder.layers.40.attention.k_proj.bias',
#  'encoder.layers.40.attention.v_proj.weight',
#  'encoder.layers.40.attention.v_proj.bias',
#  'encoder.layers.40.attention.q_proj.weight',
#  'encoder.layers.40.attention.q_proj.bias',
#  'encoder.layers.40.attention.out_proj.weight',
#  'encoder.layers.40.attention.out_proj.bias',
#  'encoder.layers.40.layer_norm.weight',
#  'encoder.layers.40.layer_norm.bias',
#  'encoder.layers.40.feed_forward.intermediate_dense.weight',
#  'encoder.layers.40.feed_forward.intermediate_dense.bias',
#  'encoder.layers.40.feed_forward.output_dense.weight',
#  'encoder.layers.40.feed_forward.output_dense.bias',
#  'encoder.layers.40.final_layer_norm.weight',
#  'encoder.layers.40.final_layer_norm.bias',
#  'encoder.layers.41.attention.k_proj.weight',
#  'encoder.layers.41.attention.k_proj.bias',
#  'encoder.layers.41.attention.v_proj.weight',
#  'encoder.layers.41.attention.v_proj.bias',
#  'encoder.layers.41.attention.q_proj.weight',
#  'encoder.layers.41.attention.q_proj.bias',
#  'encoder.layers.41.attention.out_proj.weight',
#  'encoder.layers.41.attention.out_proj.bias',
#  'encoder.layers.41.layer_norm.weight',
#  'encoder.layers.41.layer_norm.bias',
#  'encoder.layers.41.feed_forward.intermediate_dense.weight',
#  'encoder.layers.41.feed_forward.intermediate_dense.bias',
#  'encoder.layers.41.feed_forward.output_dense.weight',
#  'encoder.layers.41.feed_forward.output_dense.bias',
#  'encoder.layers.41.final_layer_norm.weight',
#  'encoder.layers.41.final_layer_norm.bias',
#  'encoder.layers.42.attention.k_proj.weight',
#  'encoder.layers.42.attention.k_proj.bias',
#  'encoder.layers.42.attention.v_proj.weight',
#  'encoder.layers.42.attention.v_proj.bias',
#  'encoder.layers.42.attention.q_proj.weight',
#  'encoder.layers.42.attention.q_proj.bias',
#  'encoder.layers.42.attention.out_proj.weight',
#  'encoder.layers.42.attention.out_proj.bias',
#  'encoder.layers.42.layer_norm.weight',
#  'encoder.layers.42.layer_norm.bias',
#  'encoder.layers.42.feed_forward.intermediate_dense.weight',
#  'encoder.layers.42.feed_forward.intermediate_dense.bias',
#  'encoder.layers.42.feed_forward.output_dense.weight',
#  'encoder.layers.42.feed_forward.output_dense.bias',
#  'encoder.layers.42.final_layer_norm.weight',
#  'encoder.layers.42.final_layer_norm.bias',
#  'encoder.layers.43.attention.k_proj.weight',
#  'encoder.layers.43.attention.k_proj.bias',
#  'encoder.layers.43.attention.v_proj.weight',
#  'encoder.layers.43.attention.v_proj.bias',
#  'encoder.layers.43.attention.q_proj.weight',
#  'encoder.layers.43.attention.q_proj.bias',
#  'encoder.layers.43.attention.out_proj.weight',
#  'encoder.layers.43.attention.out_proj.bias',
#  'encoder.layers.43.layer_norm.weight',
#  'encoder.layers.43.layer_norm.bias',
#  'encoder.layers.43.feed_forward.intermediate_dense.weight',
#  'encoder.layers.43.feed_forward.intermediate_dense.bias',
#  'encoder.layers.43.feed_forward.output_dense.weight',
#  'encoder.layers.43.feed_forward.output_dense.bias',
#  'encoder.layers.43.final_layer_norm.weight',
#  'encoder.layers.43.final_layer_norm.bias',
#  'encoder.layers.44.attention.k_proj.weight',
#  'encoder.layers.44.attention.k_proj.bias',
#  'encoder.layers.44.attention.v_proj.weight',
#  'encoder.layers.44.attention.v_proj.bias',
#  'encoder.layers.44.attention.q_proj.weight',
#  'encoder.layers.44.attention.q_proj.bias',
#  'encoder.layers.44.attention.out_proj.weight',
#  'encoder.layers.44.attention.out_proj.bias',
#  'encoder.layers.44.layer_norm.weight',
#  'encoder.layers.44.layer_norm.bias',
#  'encoder.layers.44.feed_forward.intermediate_dense.weight',
#  'encoder.layers.44.feed_forward.intermediate_dense.bias',
#  'encoder.layers.44.feed_forward.output_dense.weight',
#  'encoder.layers.44.feed_forward.output_dense.bias',
#  'encoder.layers.44.final_layer_norm.weight',
#  'encoder.layers.44.final_layer_norm.bias',
#  'encoder.layers.45.attention.k_proj.weight',
#  'encoder.layers.45.attention.k_proj.bias',
#  'encoder.layers.45.attention.v_proj.weight',
#  'encoder.layers.45.attention.v_proj.bias',
#  'encoder.layers.45.attention.q_proj.weight',
#  'encoder.layers.45.attention.q_proj.bias',
#  'encoder.layers.45.attention.out_proj.weight',
#  'encoder.layers.45.attention.out_proj.bias',
#  'encoder.layers.45.layer_norm.weight',
#  'encoder.layers.45.layer_norm.bias',
#  'encoder.layers.45.feed_forward.intermediate_dense.weight',
#  'encoder.layers.45.feed_forward.intermediate_dense.bias',
#  'encoder.layers.45.feed_forward.output_dense.weight',
#  'encoder.layers.45.feed_forward.output_dense.bias',
#  'encoder.layers.45.final_layer_norm.weight',
#  'encoder.layers.45.final_layer_norm.bias',
#  'encoder.layers.46.attention.k_proj.weight',
#  'encoder.layers.46.attention.k_proj.bias',
#  'encoder.layers.46.attention.v_proj.weight',
#  'encoder.layers.46.attention.v_proj.bias',
#  'encoder.layers.46.attention.q_proj.weight',
#  'encoder.layers.46.attention.q_proj.bias',
#  'encoder.layers.46.attention.out_proj.weight',
#  'encoder.layers.46.attention.out_proj.bias',
#  'encoder.layers.46.layer_norm.weight',
#  'encoder.layers.46.layer_norm.bias',
#  'encoder.layers.46.feed_forward.intermediate_dense.weight',
#  'encoder.layers.46.feed_forward.intermediate_dense.bias',
#  'encoder.layers.46.feed_forward.output_dense.weight',
#  'encoder.layers.46.feed_forward.output_dense.bias',
#  'encoder.layers.46.final_layer_norm.weight',
#  'encoder.layers.46.final_layer_norm.bias',
#  'encoder.layers.47.attention.k_proj.weight',
#  'encoder.layers.47.attention.k_proj.bias',
#  'encoder.layers.47.attention.v_proj.weight',
#  'encoder.layers.47.attention.v_proj.bias',
#  'encoder.layers.47.attention.q_proj.weight',
#  'encoder.layers.47.attention.q_proj.bias',
#  'encoder.layers.47.attention.out_proj.weight',
#  'encoder.layers.47.attention.out_proj.bias',
#  'encoder.layers.47.layer_norm.weight',
#  'encoder.layers.47.layer_norm.bias',
#  'encoder.layers.47.feed_forward.intermediate_dense.weight',
#  'encoder.layers.47.feed_forward.intermediate_dense.bias',
#  'encoder.layers.47.feed_forward.output_dense.weight',
#  'encoder.layers.47.feed_forward.output_dense.bias',
#  'encoder.layers.47.final_layer_norm.weight',
#  'encoder.layers.47.final_layer_norm.bias']

# %%
# Use only one time since in this i have extatct the first 48 layers weights
state_dict = checkpoint['model_state_dict']  # assuming it's saved like this

# %%
# state_dict.keys()

# %%
# Strip off "projector.wav2vec2." prefix
base_model_state_dict = {
k.replace("projector.wav2vec2.", ""): v
for k, v in state_dict.items()
if k.startswith("projector.wav2vec2.")
}

# %%
base_model_state_dict.keys()
# Out:
# dict_keys(['masked_spec_embed', 'feature_extractor.conv_layers.0.conv.weight', 'feature_extractor.conv_layers.0.conv.bias', 'feature_extractor.conv_layers.0.layer_norm.weight', 'feature_extractor.conv_layers.0.layer_norm.bias', 'feature_extractor.conv_layers.1.conv.weight', 'feature_extractor.conv_layers.1.conv.bias', 'feature_extractor.conv_layers.1.layer_norm.weight', 'feature_extractor.conv_layers.1.layer_norm.bias', 'feature_extractor.conv_layers.2.conv.weight', 'feature_extractor.conv_layers.2.conv.bias', 'feature_extractor.conv_layers.2.layer_norm.weight', 'feature_extractor.conv_layers.2.layer_norm.bias', 'feature_extractor.conv_layers.3.conv.weight', 'feature_extractor.conv_layers.3.conv.bias', 'feature_extractor.conv_layers.3.layer_norm.weight', 'feature_extractor.conv_layers.3.layer_norm.bias', 'feature_extractor.conv_layers.4.conv.weight', 'feature_extractor.conv_layers.4.conv.bias', 'feature_extractor.conv_layers.4.layer_norm.weight', 'feature_extractor.conv_layers.4.layer_norm.bias', 'feature_extractor.conv_layers.5.conv.weight', 'feature_extractor.conv_layers.5.conv.bias', 'feature_extractor.conv_layers.5.layer_norm.weight', 'feature_extractor.conv_layers.5.layer_norm.bias', 'feature_extractor.conv_layers.6.conv.weight', 'feature_extractor.conv_layers.6.conv.bias', 'feature_extractor.conv_layers.6.layer_norm.weight', 'feature_extractor.conv_layers.6.layer_norm.bias', 'feature_projection.layer_norm.weight', 'feature_projection.layer_norm.bias', 'feature_projection.projection.weight', 'feature_projection.projection.bias', 'encoder.pos_conv_embed.conv.bias', 'encoder.pos_conv_embed.conv.parametrizations.weight.original0', 'encoder.pos_conv_embed.conv.parametrizations.weight.original1', 'encoder.layer_norm.weight', 'encoder.layer_norm.bias', 'encoder.layers.0.attention.k_proj.weight', 'encoder.layers.0.attention.k_proj.bias', 'encoder.layers.0.attention.v_proj.weight', 'encoder.layers.0.attention.v_proj.bias', 'encoder.layers.0.attention.q_proj.weight', 'encoder.layers.0.attention.q_proj.bias', 'encoder.layers.0.attention.out_proj.weight', 'encoder.layers.0.attention.out_proj.bias', 'encoder.layers.0.layer_norm.weight', 'encoder.layers.0.layer_norm.bias', 'encoder.layers.0.feed_forward.intermediate_dense.weight', 'encoder.layers.0.feed_forward.intermediate_dense.bias', 'encoder.layers.0.feed_forward.output_dense.weight', 'encoder.layers.0.feed_forward.output_dense.bias', 'encoder.layers.0.final_layer_norm.weight', 'encoder.layers.0.final_layer_norm.bias', 'encoder.layers.1.attention.k_proj.weight', 'encoder.layers.1.attention.k_proj.bias', 'encoder.layers.1.attention.v_proj.weight', 'encoder.layers.1.attention.v_proj.bias', 'encoder.layers.1.attention.q_proj.weight', 'encoder.layers.1.attention.q_proj.bias', 'encoder.layers.1.attention.out_proj.weight', 'encoder.layers.1.attention.out_proj.bias', 'encoder.layers.1.layer_norm.weight', 'encoder.layers.1.layer_norm.bias', 'encoder.layers.1.feed_forward.intermediate_dense.weight', 'encoder.layers.1.feed_forward.intermediate_dense.bias', 'encoder.layers.1.feed_forward.output_dense.weight', 'encoder.layers.1.feed_forward.output_dense.bias', 'encoder.layers.1.final_layer_norm.weight', 'encoder.layers.1.final_layer_norm.bias', 'encoder.layers.2.attention.k_proj.weight', 'encoder.layers.2.attention.k_proj.bias', 'encoder.layers.2.attention.v_proj.weight', 'encoder.layers.2.attention.v_proj.bias', 'encoder.layers.2.attention.q_proj.weight', 'encoder.layers.2.attention.q_proj.bias', 'encoder.layers.2.attention.out_proj.weight', 'encoder.layers.2.attention.out_proj.bias', 'encoder.layers.2.layer_norm.weight', 'encoder.layers.2.layer_norm.bias', 'encoder.layers.2.feed_forward.intermediate_dense.weight', 'encoder.layers.2.feed_forward.intermediate_dense.bias', 'encoder.layers.2.feed_forward.output_dense.weight', 'encoder.layers.2.feed_forward.output_dense.bias', 'encoder.layers.2.final_layer_norm.weight', 'encoder.layers.2.final_layer_norm.bias', 'encoder.layers.3.attention.k_proj ...
