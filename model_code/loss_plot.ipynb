# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd

# %%
loss_0_2 = pd.read_csv('/home/IITB/ai-at-ieor/23m1508/Shivam_23M1508/Interspeech/code/model_code/model_loss_files/loss_0_2_lakh/loss_0_2_lakh.csv')

# %%
print(loss_0_2.columns)
# Out:
# Index(['step', 'epoch', 'loss', 'wer'], dtype='object')

# %%
plt.plot(loss_0_2.loc[: 500,'step'], loss_0_2.loc[: 500, 'loss'], color='blue')
plt.xlabel('Step')
plt.ylabel('Loss')
plt.title('Training Loss over Steps')
plt.grid(True)
plt.show()

# %%
loss_2_3 = pd.read_csv('/home/IITB/ai-at-ieor/23m1508/Shivam_23M1508/Interspeech/code/model_code/model_loss_files/loss_2_3_lakh/loss_2_3_lakh.csv')

# %%
plt.plot(loss_2_3['step'], loss_2_3['loss'], color='blue')
plt.xlabel('Step')
plt.ylabel('Loss')
plt.title('Training Loss over Steps')
plt.grid(True)
plt.show()
